# %% [markdown]
# # Canonical Reproduction
#
# Reproduce OPTION_1_CANONICAL with frozen blend weights.
#
# Reproduction script: `code/canonical/reproduce_canonical.py`
#
# **Run all cells from top to bottom.**

# %%
import os, sys, hashlib, json, time, warnings
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from catboost import CatBoostRegressor
from scipy.optimize import minimize

warnings.filterwarnings('ignore')

print("Environment loaded.")
print(f"Python: {sys.version}")
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"CatBoost: {__import__('catboost').__version__}")

# %% [markdown]
# ## Input Paths
#
# Edit these paths to match your environment:

# %%
DATA_DIR = "DATA/competition_data"
ARTIFACTS_DIR = "artifacts"
OUTPUT_DIR = \"submission\"\nos.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Data dir: {DATA_DIR}")
print(f"Artifacts dir: {ARTIFACTS_DIR}")
print(f"Output dir: {OUTPUT_DIR}")

# %% [markdown]
# ## Load and Validate Data
#
# Verify input file hashes before proceeding.

# %%
train_raw = pd.read_csv(os.path.join(DATA_DIR, "train.csv"))
test_raw = pd.read_csv(os.path.join(DATA_DIR, "test.csv"))
sample_sub = pd.read_csv(os.path.join(DATA_DIR, "sample_submission.csv"))
print(f"Train: {len(train_raw)} rows")
print(f"Test: {len(test_raw)} rows")
assert len(test_raw) == 1705, "Test row count mismatch"
assert list(sample_sub.columns) == ["id", "total_sales"], "Schema mismatch"

# %% [markdown]
# ## Reproduction
#
# Run the reproduction script or implement the pipeline from the documented specification.
#
# For full executable code, see:
# `code/canonical/reproduce_canonical.py`

# %%
print("For full reproduction, run:")
print("  python code/canonical/reproduce_canonical.py")
